# %% [markdown]
# <a href="https://colab.research.google.com/github/leimapapa/Easy-Deepfake-Maker/blob/main/Deepfake_Stuff.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Demo for paper "First Order Motion Model for Image Animation"

# %% [markdown]
# **Clone repository**

# %%
# !git clone https://github.com/leimapapa/first-order-model
# Out:
# Cloning into 'first-order-model'...
# remote: Enumerating objects: 150, done.
# remote: Total 150 (delta 0), reused 0 (delta 0), pack-reused 150
# Receiving objects: 100% (150/150), 58.15 MiB | 37.15 MiB/s, done.
# Resolving deltas: 100% (70/70), done.

# %%
cd first-order-model
# Out:
# /content/first-order-model

# %% [markdown]
# **Mount your Google drive folder on Colab**

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# **Add folder https://drive.google.com/drive/folders/1kZ1gCnpfU0BnpdU47pLM_TQ6RypDDqgw?usp=sharing  to your google drive.**

# %% [markdown]
# **Create a model and load checkpoints**

# %%
from demo import load_checkpoints
generator, kp_detector = load_checkpoints(config_path='config/vox-256.yaml', 
                            checkpoint_path='/content/gdrive/My Drive/first-order-motion-model/vox-cpk.pth.tar')

# %% [markdown]
# **Load driving video and source image**

# %%
import imageio
import os
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from skimage.transform import resize
from IPython.display import HTML
import warnings
warnings.filterwarnings("ignore")

media_folder = '/content/gdrive/My Drive/first-order-motion-model/'

imageName = "MonaLisa"  #@param ['ColCondrey', 'ColCondrey1', 'ColCondrey2', 'ColCondrey3', 'ColCondrey4', 'ColCondrey5', 'Khaleesi', 'BranStark', 'NedStark', 'SansaStark', 'TyrionLannister', 'TheHound', 'NightKing', 'NightKing2', 'BuzzLightyear', 'Woody', 'FreddieKrueger', 'Shrek', 'MonaLisa', 'Churchill', 'Putin', 'Reagan']
videoName = "JimCarreyMama"  #@param ['AhhKellyClarkson', 'HeresJohnny', 'ICantLie', 'JimCarreyMama', 'JimCarreySad', 'MichaelScottChina', 'Mugatu', 'NachoSmile', 'PleaseNo', 'PleaseNo1', 'SexySmile1', 'SexySmile2', 'SexySmile3', 'SexySmile4', 'SexySmile5', 'ToJail', 'ToJail2', 'Trump', 'WeAreGoingToDie', 'WeAreScrewed']

theImage = os.path.join(media_folder + imageName + '.png')
theVideo = os.path.join(media_folder + videoName + '.mp4')

source_image = imageio.imread(theImage)
driving_video = imageio.mimread(theVideo, format=None, memtest=True)

#Resize image and video to 256x256
#can it be 512?
xxx = 256

source_image = resize(source_image, (xxx, xxx))[..., :3]
driving_video = [resize(frame, (xxx, xxx))[..., :3] for frame in driving_video]

def display(source, driving, generated=None):
    fig = plt.figure(figsize=(8 + 4 * (generated is not None), 6))

    ims = []
    for i in range(len(driving)):
        cols = [source]
        cols.append(driving[i])
        if generated is not None:
            cols.append(generated[i])
        im = plt.imshow(np.concatenate(cols, axis=1), animated=True)
        plt.axis('off')
        ims.append([im])

    ani = animation.ArtistAnimation(fig, ims, interval=50, repeat_delay=1000)
    plt.close()
    return ani
    

HTML(display(source_image, driving_video).to_html5_video())
# Out:
# <video width="576" height="432" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# **Perform image animation**

# %%
from demo import make_animation
from skimage import img_as_ubyte

predictions = make_animation(source_image, driving_video, generator, kp_detector, relative=True)

#save resulting video
imageio.mimsave('../generated.mp4', [img_as_ubyte(frame) for frame in predictions])
#video can be downloaded from /content folder

HTML(display(source_image, driving_video, predictions).to_html5_video())
# Out:
# 100%|██████████| 101/101 [00:12<00:00,  7.82it/s]
# <video width="864" height="432" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# **In the cell above we use relative keypoint displacement to animate the objects. We can use absolute coordinates instead,  but in this way all the object proporions will be inherited from the driving video. For example Putin haircut will be extended to match Trump haircut.**

# %%
predictions = make_animation(source_image, driving_video, generator, kp_detector, relative=False, adapt_movement_scale=True)
HTML(display(source_image, driving_video, predictions).to_html5_video())
# Out:
# 100%|██████████| 280/280 [00:10<00:00, 26.76it/s]
# <video width="864" height="432" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# ## Running on your data
#
# **First we need to crop a face from both source image and video, while simple graphic editor like paint can be used for cropping from image. Cropping from video is more complicated. You can use ffpmeg for this.**

# %%
# !ffmpeg -i /content/gdrive/My\ Drive/first-order-motion-model/07.mkv -ss 00:08:57.50 -t 00:00:08 -filter:v "crop=600:600:760:50" -async 1 output.mp4
# Out:
# ffmpeg version 3.4.6-0ubuntu0.18.04.1 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
# ...

# %% [markdown]
# **Another posibility is to use some screen recording tool, or if you need to crop many images at once use face detector(https://github.com/1adrianb/face-alignment) , see https://github.com/AliaksandrSiarohin/video-preprocessing for preprcessing of VoxCeleb.**

# %%
source_image = imageio.imread('/content/gdrive/My Drive/first-order-motion-model/09.png')
driving_video = imageio.mimread('output.mp4', memtest=False)


#Resize image and video to 256x256

source_image = resize(source_image, (256, 256))[..., :3]
driving_video = [resize(frame, (256, 256))[..., :3] for frame in driving_video]

predictions = make_animation(source_image, driving_video, generator, kp_detector, relative=True,
                             adapt_movement_scale=True)

HTML(display(source_image, driving_video, predictions).to_html5_video())
# Out:
# 100%|██████████| 240/240 [00:08<00:00, 29.00it/s]
# <video width="864" height="432" controls autoplay loop>
#   <source type="video/mp4" src="...
